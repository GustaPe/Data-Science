# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/Trabalho/2021_Viagem - Limpo.csv',
                    sep=',', encoding='utf-8')

# %%
df.head()
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             16889781                 000120/20
# 1                             16910306                 000076/20
# 2                             16911615                 000139/20
# 3                             17059467           Informações pro
# 4                             17063782                 000001/21
#
#         Situação Viagem Urgente  \
# 0  Não realizada            não
# 1  Não realizada            não
# 2  Não realizada            não
# 3      Realizada            não
# 4  Não realizada            não
#
#                        Justificativa Urgência Viagem  \
# 0                                     Sem informação
# 1                                     Sem informação
# 2                                     Sem informação
# 3  Informação protegida por sigilo nos termos da ...
# 4                                     Sem informação
#
#    Código do órgão superior  \
# 0                     26000
# 1                     20113
# 2                     26000
# 3                     30000
# 4                     26000
#
#                               Nome do órgão superior  \
# 0                             Ministério da Educação
# 1  Ministério do Planejamento, Desenvolvimento e ...
# 2                             Ministério da Educação
# 3          Ministério da Justiça e Segurança Pública
# 4                             Ministério da Educação
#
#    Código órgão solicitante                      Nome órgão solicitante  \
# 0                     26281    Fundação Universidade Federal de Sergipe
# 1                     25206    Instituto de Pesquisa Econômica Aplicada
# 2                     26352        Fundação Universidade Federal do ABC
# 3                     30802  Departamento de Polícia Rodoviária Federal
# 4                     26247         Universidade Federal de Santa Maria
#
#      CPF viajante  ...    Função                   Descrição Função  \
# 0  ***.157.645-**  ...   FG-0001                            FG-0001
# 1  ***.442.331-**  ...        -1                      Não Informado
# 2  ***.044.178-**  ...   FG-0001                            FG-0001
# 3     ID061300104  ...  Sigilosa  Informações protegidas por sigilo
# 4  ***.516.500-**  ...        -1                      Não Informado
#
#   Período - Data de início Período - Data de fim  \
# 0               2021-11-05            2021-05-16
# 1               2021-02-23            2021-02-23
# 2               2021-04-24            2021-04-28
# 3               2021-04-01            2021-04-01
# 4               2021-01-29            2021-02-06
#
#                             Destinos  \
# 0                       Fortaleza/CE
# 1                    Porto Alegre/RS
# 2                  Belo Horizonte/MG
# 3  Informações protegidas por sigilo
# 4                Norwich/Reino Unido
#
#                                               Motivo Valor diárias  \
# 0  Participação no XXI Congresso Nacional de Secr...          0,00
# 1  Apresentação de artigo em congresso internacio...          0,00
# 2  Participação da UFABC na Associação Brasileira...          0,00
# 3  Informação protegida por sigilo nos termos da ...          0,00
# 4  O proposto Cristian de Sales Dambros, realizar...          0,00
#
#   Valor passagens Valor devolução Valor outros gastos
# 0         1179,77            0,00                0,00
# 1         1026,49            0,00                0,00
# 2          362,70            0,00                0,00
# 3         1339,47            0,00                0,00
# 4            0,00            0,00                0,00
#
# [5 rows x 22 columns]

# %%
import plotly.express as px

# %%
histograma =  px.histogram (df,  x = "Situação", nbins=60) 
histograma.update_layout(width=600,height=400,title_text='Situação das Viagens') 
histograma.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
histograma =  px.histogram (df,  x = "Viagem Urgente", nbins=60) 
histograma.update_layout(width=600,height=400,title_text='Situação das Viagens') 
histograma.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.head(1)
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             16889781                 000120/20
#
#         Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0  Não realizada            não                Sem informação
#
#    Código do órgão superior  Nome do órgão superior  Código órgão solicitante  \
# 0                     26000  Ministério da Educação                     26281
#
#                      Nome órgão solicitante    CPF viajante  ...   Função  \
# 0  Fundação Universidade Federal de Sergipe  ***.157.645-**  ...  FG-0001
#
#   Descrição Função Período - Data de início Período - Data de fim  \
# 0          FG-0001               2021-11-05            2021-05-16
#
#        Destinos                                             Motivo  \
# 0  Fortaleza/CE  Participação no XXI Congresso Nacional de Secr...
#
#   Valor diárias Valor passagens Valor devolução Valor outros gastos
# 0          0,00         1179,77            0,00                0,00
#
# [1 rows x 22 columns]

# %%
df.rename(columns={'Identificador do processo de viagem': 'ID'}, inplace=True)
df.rename(columns={'Número da Proposta (PCDP)': 'NP'}, inplace=True)
df.rename(columns={'Código do órgão superior': 'CSUP'}, inplace=True)
df.rename(columns={'Nome do órgão superior': 'NomeSUP'}, inplace=True)
df.rename(columns={'Código órgão solicitante': 'CSLC'}, inplace=True)
df.rename(columns={'Nome órgão solicitante': 'NomeSLC'}, inplace=True)
df.rename(columns={'CPF viajante': 'CPF'}, inplace=True)
df.rename(columns={'Período - Data de início': 'Data de início'}, inplace=True)
df.rename(columns={'Período - Data de fim': 'Data de fim'}, inplace=True)

# %%
df.head(1)
# Out:
#          ID         NP       Situação Viagem Urgente  \
# 0  16889781  000120/20  Não realizada            não
#
#   Justificativa Urgência Viagem   CSUP                 NomeSUP   CSLC  \
# 0                Sem informação  26000  Ministério da Educação  26281
#
#                                     NomeSLC             CPF  ...   Função  \
# 0  Fundação Universidade Federal de Sergipe  ***.157.645-**  ...  FG-0001
#
#   Descrição Função Data de início Data de fim      Destinos  \
# 0          FG-0001     2021-11-05  2021-05-16  Fortaleza/CE
#
#                                               Motivo Valor diárias  \
# 0  Participação no XXI Congresso Nacional de Secr...          0,00
#
#   Valor passagens Valor devolução Valor outros gastos
# 0         1179,77            0,00                0,00
#
# [1 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# ID                               0
# NP                               0
# Situação                         0
# Viagem Urgente                   0
# Justificativa Urgência Viagem    0
# CSUP                             0
# NomeSUP                          0
# CSLC                             0
# NomeSLC                          0
# CPF                              0
# Nome                             0
# Cargo                            0
# Função                           0
# Descrição Função                 0
# Data de início                   0
# Data de fim                      0
# Destinos                         0
# Motivo                           0
# Valor diárias                    0
# Valor passagens                  0
# Valor devolução                  0
# Valor outros gastos              0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, NP, Situação, Viagem Urgente, Justificativa Urgência Viagem, CSUP, NomeSUP, CSLC, NomeSLC, CPF, Nome, Cargo, Função, Descrição Função, Data de início, Data de fim, Destinos, Motivo, Valor diárias, Valor passagens, Valor devolução, Valor outros gastos]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.dropna(inplace=True)

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, NP, Situação, Viagem Urgente, Justificativa Urgência Viagem, CSUP, NomeSUP, CSLC, NomeSLC, CPF, Nome, Cargo, Função, Descrição Função, Data de início, Data de fim, Destinos, Motivo, Valor diárias, Valor passagens, Valor devolução, Valor outros gastos]
# Index: []
#
# [0 rows x 22 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, NP, Situação, Viagem Urgente, Justificativa Urgência Viagem, CSUP, NomeSUP, CSLC, NomeSLC, CPF, Nome, Cargo, Função, Descrição Função, Data de início, Data de fim, Destinos, Motivo, Valor diárias, Valor passagens, Valor devolução, Valor outros gastos]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# ID                               0
# NP                               0
# Situação                         0
# Viagem Urgente                   0
# Justificativa Urgência Viagem    0
# CSUP                             0
# NomeSUP                          0
# CSLC                             0
# NomeSLC                          0
# CPF                              0
# Nome                             0
# Cargo                            0
# Função                           0
# Descrição Função                 0
# Data de início                   0
# Data de fim                      0
# Destinos                         0
# Motivo                           0
# Valor diárias                    0
# Valor passagens                  0
# Valor devolução                  0
# Valor outros gastos              0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                                int64
# NP                               object
# Situação                         object
# Viagem Urgente                   object
# Justificativa Urgência Viagem    object
# CSUP                              int64
# NomeSUP                          object
# CSLC                              int64
# NomeSLC                          object
# CPF                              object
# Nome                             object
# Cargo                            object
# Função                           object
# Descrição Função                 object
# Data de início                   object
# Data de fim                      object
# Destinos                         object
# Motivo                           object
# Valor diárias                    object
# Valor passagens                  object
# Valor devolução                  object
# Valor outros gastos              object
# dtype: object

# %%
df.describe()
# Out:
#                  ID           CSUP           CSLC
# count  2.249610e+05  224961.000000  224961.000000
# mean   1.888214e+07   28173.982650   27267.062104
# std    5.188463e+07   11001.003626   10326.989972
# min    1.688978e+07      -1.000000      -1.000000
# 25%    1.740809e+07   25000.000000   25205.000000
# 50%    1.754072e+07   30000.000000   30108.000000
# 75%    1.766836e+07   30000.000000   30802.000000
# max    2.022000e+09   63000.000000   64000.000000

# %%
import plotly.express as px

# %%
boxplot = px.box(df, y="Destinos")
boxplot.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df2 = df.drop(labels = 'NP', axis = 1)

# %%
df2.head(3)
# Out:
#          ID       Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0  16889781  Não realizada            não                Sem informação
# 1  16910306  Não realizada            não                Sem informação
# 2  16911615  Não realizada            não                Sem informação
#
#     CSUP                                            NomeSUP   CSLC  \
# 0  26000                             Ministério da Educação  26281
# 1  20113  Ministério do Planejamento, Desenvolvimento e ...  25206
# 2  26000                             Ministério da Educação  26352
#
#                                     NomeSLC             CPF  \
# 0  Fundação Universidade Federal de Sergipe  ***.157.645-**
# 1  Instituto de Pesquisa Econômica Aplicada  ***.442.331-**
# 2      Fundação Universidade Federal do ABC  ***.044.178-**
#
#                               Nome  ...   Função Descrição Função  \
# 0       ROSE MARY SILVEIRA MENEZES  ...  FG-0001          FG-0001
# 1           IGOR FERRAZ DA FONSECA  ...       -1    Não Informado
# 2  NATALIA CARDOSO ABREU DE ARAUJO  ...  FG-0001          FG-0001
#
#   Data de início Data de fim           Destinos  \
# 0     2021-11-05  2021-05-16       Fortaleza/CE
# 1     2021-02-23  2021-02-23    Porto Alegre/RS
# 2     2021-04-24  2021-04-28  Belo Horizonte/MG
#
#                                               Motivo Valor diárias  \
# 0  Participação no XXI Congresso Nacional de Secr...          0,00
# 1  Apresentação de artigo em congresso internacio...          0,00
# 2  Participação da UFABC na Associação Brasileira...          0,00
#
#   Valor passagens Valor devolução Valor outros gastos
# 0         1179,77            0,00                0,00
# 1         1026,49            0,00                0,00
# 2          362,70            0,00                0,00
#
# [3 rows x 21 columns]

# %%
df2['Motivo'].replace({'Left': 0, 'Right': 1}, inplace=True)

# %%
df2.head(1)
# Out:
#          ID       Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0  16889781  Não realizada            não                Sem informação
#
#     CSUP                 NomeSUP   CSLC  \
# 0  26000  Ministério da Educação  26281
#
#                                     NomeSLC             CPF  \
# 0  Fundação Universidade Federal de Sergipe  ***.157.645-**
#
#                          Nome  ...   Função Descrição Função Data de início  \
# 0  ROSE MARY SILVEIRA MENEZES  ...  FG-0001          FG-0001     2021-11-05
#
#   Data de fim      Destinos  \
# 0  2021-05-16  Fortaleza/CE
#
#                                               Motivo Valor diárias  \
# 0  Participação no XXI Congresso Nacional de Secr...          0,00
#
#   Valor passagens Valor devolução Valor outros gastos
# 0         1179,77            0,00                0,00
#
# [1 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
df
# Out:
#                 ID               NP       Situação Viagem Urgente  \
# 0         16889781        000120/20  Não realizada            não
# 1         16910306        000076/20  Não realizada            não
# 2         16911615        000139/20  Não realizada            não
# 3         17059467  Informações pro      Realizada            não
# 4         17063782        000001/21  Não realizada            não
# ...            ...              ...            ...            ...
# 224956  2021000356   Sem informação      Realizada            não
# 224957  2021000403   Sem informação      Realizada            não
# 224958  2021000416   Sem informação      Realizada            não
# 224959  2021000423   Sem informação      Realizada            não
# 224960  2022000007   Sem informação      Realizada            não
#
#                             Justificativa Urgência Viagem   CSUP  \
# 0                                          Sem informação  26000
# 1                                          Sem informação  20113
# 2                                          Sem informação  26000
# 3       Informação protegida por sigilo nos termos da ...  30000
# 4                                          Sem informação  26000
# ...                                                   ...    ...
# 224956                                     Sem informação  25201
# 224957                                     Sem informação  25201
# 224958                                     Sem informação  25201
# 224959                                     Sem informação  25201
# 224960                                     Sem informação  25201
#
#                                                   NomeSUP   CSLC  \
# 0                                  Ministério da Educação  26281
# 1       Ministério do Planejamento, Desenvolvimento e ...  25206
# 2                                  Ministério da Educação  26352
# 3               Ministério da Justiça e Segurança Pública  30802
# 4                                  Ministério da Educação  26247
# ...                                                   ...    ...
# 224956  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224957  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224958  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224959  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224960  Banco Central do Brasil - Orçamento Fiscal e S...  25201
#
#                                                   NomeSLC             CPF  \
# 0                Fundação Universidade Federal de Sergipe  ***.157.645-**
# 1                Instituto de Pesquisa Econômica Aplicada  ***.442.331-**
# 2                    Fundação Universidade Federal do ABC  ***.044.178-**
# 3              Departamento de Polícia Rodoviária Federal     ID061300104
# 4                     Universidade Federal de Santa Maria  ***.516.500-**
# ...                                                   ...             ...
# 224956  Banco Central do Brasil - Orçamento Fiscal e S...  ***.602.017-**
# 224957  Banco Central do Brasil - Orçamento Fiscal e S...  ***.108.167-**
# 224958  Banco Central do Brasil - Orçamento Fiscal e S...  ***.602.017-**
# 224959  Banco Central do Brasil - Orçamento Fiscal e S...  ***.595.338-**
# 224960  Banco Central do Brasil - Orçamento Fiscal e S...  ***.952.927-**
#
#         ...    Função                   Descrição Função Data de início  \
# 0       ...   FG-0001                            FG-0001     2021-11-05
# 1       ...        -1                      Não Informado     2021-02-23
# 2       ...   FG-0001                            FG-0001     2021-04-24
# 3       ...  Sigilosa  Informações protegidas por sigilo     2021-04-01
# 4       ...        -1                      Não Informado     2021-01-29
# ...     ...       ...                                ...            ...
# 224956  ...        -1                      Não Informado     2021-09-12
# 224957  ...        -1                      Não Informado     2021-12-16
# 224958  ...        -1                      Não Informado     2021-12-17
# 224959  ...        -1                      Não Informado     2021-12-16
# 224960  ...        -1                      Não Informado     2021-10-25
#
#        Data de fim                           Destinos  \
# 0       2021-05-16                       Fortaleza/CE
# 1       2021-02-23                    Porto Alegre/RS
# 2       2021-04-28                  Belo Horizonte/MG
# 3       2021-04-01  Informações protegidas por sigilo
# 4       2021-02-06                Norwich/Reino Unido
# ...            ...                                ...
# 224956  2021-12-13                     Sem informação
# 224957  2022-03-01                     Sem informação
# 224958  2021-12-17                     Sem informação
# 224959  2021-12-24                     Sem informação
# 224960  2021-10-25                     Sem informação
#
#                                                    Motivo Valor diárias  \
# 0       Participação no XXI Congresso Nacional de Secr...          0,00
# 1       Apresentação de artigo em congresso internacio...          0,00
# 2       Participação da UFABC na Associação Brasileira...          0,00
# 3       Informação protegida por sigilo nos termos da ...          0,00
# 4       O proposto Cristian de Sales Dambros, realizar...          0,00
# ...                                                   ...           ...
# 224956                        Cumprir agenda em São Paulo          0,00
# 224957     Cumprir agenda de trabalhos no Rio de Janeiro.          0,00
# 224958                       Cumprir agenda em São Paulo.          0,00
# 224959                       Cumprir agenda em São Paulo.          0,00
# 224960  Remoção por ofício do servidor e 1 dependente ...          0,00
#
#        Valor passagens Valor devolução Valor outros gastos
# 0              1179,77            0,00                0,00
# 1              1026,49            0,00                0,00
# 2               362,70            0,00                0,00
# 3              1339,47            0,00                0,00
# 4                 0,00            0,00                0,00
# ...                ...             ...                 ...
# 224956         2360,09            0,00                0,00
# 224957          930,23            0,00                0,00
# 224958         1195,53            0,00                0,00
# 224959         1004,76            0,00                0,00
# 224960            0,00            0,00              192,00
#
# [224961 rows x 22 columns]

# %%
info = df.iloc[:, [5]].values

# %%
info
# Out:
# array([[26000],
#        [20113],
#        [26000],
#        ...,
#        [25201],
#        [25201],
#        [25201]])

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 5, max_iter = 300)
    kmeans.fit(info)
   
    wcss.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
sns.lineplot(range(1, 11), wcss,marker='o',color='green')
plt.title('The Elbow Method')
plt.xlabel('Número de clusters')
plt.ylabel('WCSS');

# %%
kmeans = KMeans(n_clusters = 6, init = 'k-means++', random_state = 5, max_iter = 300)

# %%
kmeans = kmeans.fit(info)

# %%
centroides = kmeans.cluster_centers_
centroides
# Out:
# array([[ 3.00280072e+04],
#        [-1.00000001e+00],
#        [ 4.40000000e+04],
#        [ 2.41536632e+04],
#        [ 3.83070809e+04],
#        [ 5.39480697e+04]])

# %%
order = kmeans.labels_
order
# Out:
# array([3, 3, 3, ..., 3, 3, 3], dtype=int32)

# %%
order02 = pd.DataFrame(order, columns = ['Grupo'])
order02
# Out:
#         Grupo
# 0           3
# 1           3
# 2           3
# 3           0
# 4           3
# ...       ...
# 224956      3
# 224957      3
# 224958      3
# 224959      3
# 224960      3
#
# [224961 rows x 1 columns]

# %%
df2 = pd.concat([df, order02],axis=1)
df2
# Out:
#                 ID               NP       Situação Viagem Urgente  \
# 0         16889781        000120/20  Não realizada            não
# 1         16910306        000076/20  Não realizada            não
# 2         16911615        000139/20  Não realizada            não
# 3         17059467  Informações pro      Realizada            não
# 4         17063782        000001/21  Não realizada            não
# ...            ...              ...            ...            ...
# 224956  2021000356   Sem informação      Realizada            não
# 224957  2021000403   Sem informação      Realizada            não
# 224958  2021000416   Sem informação      Realizada            não
# 224959  2021000423   Sem informação      Realizada            não
# 224960  2022000007   Sem informação      Realizada            não
#
#                             Justificativa Urgência Viagem   CSUP  \
# 0                                          Sem informação  26000
# 1                                          Sem informação  20113
# 2                                          Sem informação  26000
# 3       Informação protegida por sigilo nos termos da ...  30000
# 4                                          Sem informação  26000
# ...                                                   ...    ...
# 224956                                     Sem informação  25201
# 224957                                     Sem informação  25201
# 224958                                     Sem informação  25201
# 224959                                     Sem informação  25201
# 224960                                     Sem informação  25201
#
#                                                   NomeSUP   CSLC  \
# 0                                  Ministério da Educação  26281
# 1       Ministério do Planejamento, Desenvolvimento e ...  25206
# 2                                  Ministério da Educação  26352
# 3               Ministério da Justiça e Segurança Pública  30802
# 4                                  Ministério da Educação  26247
# ...                                                   ...    ...
# 224956  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224957  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224958  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224959  Banco Central do Brasil - Orçamento Fiscal e S...  25201
# 224960  Banco Central do Brasil - Orçamento Fiscal e S...  25201
#
#                                                   NomeSLC             CPF  \
# 0                Fundação Universidade Federal de Sergipe  ***.157.645-**
# 1                Instituto de Pesquisa Econômica Aplicada  ***.442.331-**
# 2                    Fundação Universidade Federal do ABC  ***.044.178-**
# 3              Departamento de Polícia Rodoviária Federal     ID061300104
# 4                     Universidade Federal de Santa Maria  ***.516.500-**
# ...                                                   ...             ...
# 224956  Banco Central do Brasil - Orçamento Fiscal e S...  ***.602.017-**
# 224957  Banco Central do Brasil - Orçamento Fiscal e S...  ***.108.167-**
# 224958  Banco Central do Brasil - Orçamento Fiscal e S...  ***.602.017-**
# 224959  Banco Central do Brasil - Orçamento Fiscal e S...  ***.595.338-**
# 224960  Banco Central do Brasil - Orçamento Fiscal e S...  ***.952.927-**
#
#         ...                   Descrição Função Data de início Data de fim  \
# 0       ...                            FG-0001     2021-11-05  2021-05-16
# 1       ...                      Não Informado     2021-02-23  2021-02-23
# 2       ...                            FG-0001     2021-04-24  2021-04-28
# 3       ...  Informações protegidas por sigilo     2021-04-01  2021-04-01
# 4       ...                      Não Informado     2021-01-29  2021-02-06
# ...     ...                                ...            ...         ...
# 224956  ...                      Não Informado     2021-09-12  2021-12-13
# 224957  ...                      Não Informado     2021-12-16  2022-03-01
# 224958  ...                      Não Informado     2021-12-17  2021-12-17
# 224959  ...                      Não Informado     2021-12-16  2021-12-24
# 224960  ...                      Não Informado     2021-10-25  2021-10-25
#
#                                  Destinos  \
# 0                            Fortaleza/CE
# 1                         Porto Alegre/RS
# 2                       Belo Horizonte/MG
# 3       Informações protegidas por sigilo
# 4                     Norwich/Reino Unido
# ...                                   ...
# 224956                     Sem informação
# 224957                     Sem informação
# 224958                     Sem informação
# 224959                     Sem informação
# 224960                     Sem informação
#
#                                                    Motivo Valor diárias  \
# 0       Participação no XXI Congresso Nacional de Secr...          0,00
# 1       Apresentação de artigo em congresso internacio...          0,00
# 2       Participação da UFABC na Associação Brasileira...          0,00
# 3       Informação protegida por sigilo nos termos da ...          0,00
# 4       O proposto Cristian de Sales Dambros, realizar...          0,00
# ...                                                   ...           ...
# 224956                        Cumprir agenda em São Paulo          0,00
# 224957     Cumprir agenda de trabalhos no Rio de Janeiro.          0,00
# 224958                       Cumprir agenda em São Paulo.          0,00
# 224959                       Cumprir agenda em São Paulo.          0,00
# 224960  Remoção por ofício do servidor e 1 dependente ...          0,00
#
#        Valor passagens Valor devolução Valor outros gastos Grupo
# 0              1179,77            0,00                0,00     3
# 1              1026,49            0,00                0,00     3
# 2               362,70            0,00                0,00     3
# 3              1339,47            0,00                0,00     0
# 4                 0,00            0,00                0,00     3
# ...                ...             ...                 ...   ...
# 224956         2360,09            0,00                0,00     3
# 224957          930,23            0,00                0,00     3
# 224958         1195,53            0,00                0,00     3
# 224959         1004,76            0,00                0,00     3
# 224960            0,00            0,00              192,00     3
#
# [224961 rows x 23 columns]

# %%
df2.iloc[100, :]
# Out:
# ID                                                                        17244959
# NP                                                                       000108/21
# Situação                                                                 Realizada
# Viagem Urgente                                                                 não
# Justificativa Urgência Viagem                                       Sem informação
# CSUP                                                                         35000
# NomeSUP                                         Ministério das Relações Exteriores
# CSLC                                                                         35000
# NomeSLC                          Ministério das Relações Exteriores - Unidades ...
# CPF                                                                 ***.285.881-**
# Nome                                                 MAGDA ROSA OTTONI DE CARVALHO
# Cargo                                                    ASSISTENTE DE CHANCELARIA
# Função                                                                          -1
# Descrição Função                                                     Não Informado
# Data de início                                                          2021-04-01
# Data de fim                                                             2021-11-01
# Destinos                                                               Brasília/DF
# Motivo                           REMOVIDA DE BRASEMB LIMA PARA A SERE.VIAJA ACO...
# Valor diárias                                                                 0,00
# Valor passagens                                                            4926,21
# Valor devolução                                                               0,00
# Valor outros gastos                                                           0,00
# Grupo                                                                            4
# Name: 100, dtype: object

# %%
df2.loc[df2.ID == 76]
# Out:
# Empty DataFrame
# Columns: [ID, NP, Situação, Viagem Urgente, Justificativa Urgência Viagem, CSUP, NomeSUP, CSLC, NomeSLC, CPF, Nome, Cargo, Função, Descrição Função, Data de início, Data de fim, Destinos, Motivo, Valor diárias, Valor passagens, Valor devolução, Valor outros gastos, Grupo]
# Index: []
#
# [0 rows x 23 columns]

# %%
group = df2.loc[df2.Grupo == 0]
group
# Out:
#               ID               NP   Situação Viagem Urgente  \
# 3       17059467  Informações pro  Realizada            não
# 24      17190691  Informações pro  Realizada            não
# 36      17208003  Informações pro  Realizada            não
# 43      17215715  Informações pro  Realizada            não
# 50      17221892  Informações pro  Realizada            não
# ...          ...              ...        ...            ...
# 224793  17967432  Informações pro  Realizada            não
# 224794  17967457  Informações pro  Realizada            não
# 224797  17990954  Informações pro  Realizada            não
# 224798  17991129  Informações pro  Realizada            não
# 224801  18040635  Informações pro  Realizada            não
#
#                             Justificativa Urgência Viagem   CSUP  \
# 3       Informação protegida por sigilo nos termos da ...  30000
# 24      Informação protegida por sigilo nos termos da ...  30000
# 36      Informação protegida por sigilo nos termos da ...  30000
# 43      Informação protegida por sigilo nos termos da ...  30000
# 50      Informação protegida por sigilo nos termos da ...  30000
# ...                                                   ...    ...
# 224793  Informação protegida por sigilo nos termos da ...  30000
# 224794  Informação protegida por sigilo nos termos da ...  30000
# 224797  Informação protegida por sigilo nos termos da ...  30000
# 224798  Informação protegida por sigilo nos termos da ...  30000
# 224801  Informação protegida por sigilo nos termos da ...  30000
#
#                                           NomeSUP   CSLC  \
# 3       Ministério da Justiça e Segurança Pública  30802
# 24      Ministério da Justiça e Segurança Pública  30108
# 36      Ministério da Justiça e Segurança Pública  30108
# 43      Ministério da Justiça e Segurança Pública  30108
# 50      Ministério da Justiça e Segurança Pública  30108
# ...                                           ...    ...
# 224793  Ministério da Justiça e Segurança Pública  30802
# 224794  Ministério da Justiça e Segurança Pública  30802
# 224797  Ministério da Justiça e Segurança Pública  30802
# 224798  Ministério da Justiça e Segurança Pública  30802
# 224801  Ministério da Justiça e Segurança Pública  30108
#
#                                            NomeSLC          CPF  ...  \
# 3       Departamento de Polícia Rodoviária Federal  ID061300104  ...
# 24                 Departamento de Polícia Federal  ID006900270  ...
# 36                 Departamento de Polícia Federal  ID010900249  ...
# 43                 Departamento de Polícia Federal  ID012900338  ...
# 50                 Departamento de Polícia Federal  ID010800154  ...
# ...                                            ...          ...  ...
# 224793  Departamento de Polícia Rodoviária Federal  ID009600260  ...
# 224794  Departamento de Polícia Rodoviária Federal  ID009600260  ...
# 224797  Departamento de Polícia Rodoviária Federal  ID128400100  ...
# 224798  Departamento de Polícia Rodoviária Federal  ID162900101  ...
# 224801             Departamento de Polícia Federal  ID000200219  ...
#
#                          Descrição Função Data de início Data de fim  \
# 3       Informações protegidas por sigilo     2021-04-01  2021-04-01
# 24      Informações protegidas por sigilo     2021-01-01  2021-05-16
# 36      Informações protegidas por sigilo     2021-01-20  2021-01-21
# 43      Informações protegidas por sigilo     2021-05-01  2021-05-03
# 50      Informações protegidas por sigilo     2021-03-01  2021-06-02
# ...                                   ...            ...         ...
# 224793  Informações protegidas por sigilo     2021-06-12  2021-10-12
# 224794  Informações protegidas por sigilo     2021-12-12  2021-12-24
# 224797  Informações protegidas por sigilo     2021-12-27  2021-12-31
# 224798  Informações protegidas por sigilo     2021-12-27  2021-12-31
# 224801  Informações protegidas por sigilo     2021-12-30  2021-12-30
#
#                                  Destinos  \
# 3       Informações protegidas por sigilo
# 24      Informações protegidas por sigilo
# 36      Informações protegidas por sigilo
# 43      Informações protegidas por sigilo
# 50      Informações protegidas por sigilo
# ...                                   ...
# 224793  Informações protegidas por sigilo
# 224794  Informações protegidas por sigilo
# 224797  Informações protegidas por sigilo
# 224798  Informações protegidas por sigilo
# 224801  Informações protegidas por sigilo
#
#                                                    Motivo Valor diárias  \
# 3       Informação protegida por sigilo nos termos da ...          0,00
# 24      Informação protegida por sigilo nos termos da ...      28442,84
# 36      Informação protegida por sigilo nos termos da ...          0,00
# 43      Informação protegida por sigilo nos termos da ...       9710,42
# 50      Informação protegida por sigilo nos termos da ...       7309,40
# ...                                                   ...           ...
# 224793  Informação protegida por sigilo nos termos da ...        798,60
# 224794  Informação protegida por sigilo nos termos da ...       2299,30
# 224797  Informação protegida por sigilo nos termos da ...        851,70
# 224798  Informação protegida por sigilo nos termos da ...        851,70
# 224801  Informação protegida por sigilo nos termos da ...         79,48
#
#        Valor passagens Valor devolução Valor outros gastos Grupo
# 3              1339,47            0,00                0,00     0
# 24              302,96            0,00                0,00     0
# 36             8250,26            0,00                0,00     0
# 43              597,70            0,00                0,00     0
# 50             3797,75            0,00                0,00     0
# ...                ...             ...                 ...   ...
# 224793            0,00            0,00                0,00     0
# 224794            0,00            0,00                0,00     0
# 224797            0,00            0,00                0,00     0
# 224798            0,00            0,00                0,00     0
# 224801            0,00            0,00                0,00     0
#
# [91405 rows x 23 columns]

# %%
group.shape
# Out:
# (91405, 23)

# %%
info[5,:]
# Out:
# array([35000])

# %%
order[5]
# Out:
# 4
