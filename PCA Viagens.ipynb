# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/Trabalho/2021_Viagem - Limpo.csv',
                    sep=',', encoding='UTF-8')

# %%
df.head()
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             16889781                 000120/20
# 1                             16910306                 000076/20
# 2                             16911615                 000139/20
# 3                             17059467           Informações pro
# 4                             17063782                 000001/21
#
#         Situação Viagem Urgente  \
# 0  Não realizada            não
# 1  Não realizada            não
# 2  Não realizada            não
# 3      Realizada            não
# 4  Não realizada            não
#
#                        Justificativa Urgência Viagem  \
# 0                                     Sem informação
# 1                                     Sem informação
# 2                                     Sem informação
# 3  Informação protegida por sigilo nos termos da ...
# 4                                     Sem informação
#
#    Código do órgão superior  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_pca = df.iloc[:,:].values
df_pca
# Out:
# array([[16889781, '000120/20', 'Não realizada', ..., '1179,77', '0,00',
#         '0,00'],
#        [16910306, '000076/20', 'Não realizada', ..., '1026,49', '0,00',
#         '0,00'],
#        [16911615, '000139/20', 'Não realizada', ..., '362,70', '0,00',
#         '0,00'],
#        ...,
#        [2021000416, 'Sem informação', 'Realizada', ..., '1195,53',
#         '0,00', '0,00'],
#        [2021000423, 'Sem informação', 'Realizada', ..., '1004,76',
#         '0,00', '0,00'],
#        [2022000007, 'Sem informação', 'Realizada', ..., '0,00', '0,00',
#         '192,00']], dtype=object)

# %%
lbl = LabelEncoder()
df_pca = lbl.fit_transform(df_pca[:,1])
df_pca
# Out:
# array([  321,   200,   374, ..., 28674, 28674, 28674])

# %%
list(lbl.classes_)
# Out:
# ['000001/21',
#  '000001/21-1C',
#  '000001/21-2C',
#  '000002/21',
#  '000002/21-1C',
#  '000003/21',
#  '000003/21-1C',
#  '000003/21-3C',
#  '000004/21',
#  '000004/21-1C',
#  '000004/21-2C',
#  '000005/21',
#  '000005/21-1C',
#  '000005/21-2C',
#  '000006/21',
#  '000006/21-1C',
#  '000006/21-2C',
#  '000006/21-3C',
#  '000007/21',
#  '000007/21-1C',
#  '000007/21-2C',
#  '000008/21',
#  '000008/21-1C',
#  '000009/21',
#  '000009/21-1C',
#  '000010/21',
#  '000010/21-1C',
#  '000010/21-2C',
#  '000010/21-4C',
#  '000011/21',
#  '000011/21-1C',
#  '000012/21',
#  '000012/21-1C',
#  '000012/21-2C',
#  '000013/21',
#  '000013/21-1C',
#  '000013/21-4C',
#  '000014/21',
#  '000014/21-1C',
#  '000015/21',
#  '000015/21-1C',
#  '000016/21',
#  '000016/21-1C',
#  '000017/21',
#  '000017/21-1C',
#  '000018/21',
#  '000018/21-1C',
#  '000018/21-2C',
#  '000019/21',
#  '000019/21-1C',
#  '000019/21-3C',
#  '000020/21',
#  '000020/21-1C',
#  '000021/21',
#  '000021/21-1C',
#  '000022/21',
# ...

# %%
df['Valores'] = df_pca
df.head()
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             16889781                 000120/20
# 1                             16910306                 000076/20
# 2                             16911615                 000139/20
# 3                             17059467           Informações pro
# 4                             17063782                 000001/21
#
#         Situação  Viagem Urgente  \
# 0  Não realizada             321
# 1  Não realizada             200
# 2  Não realizada             374
# 3      Realizada           28673
# 4  Não realizada               0
#
#                        Justificativa Urgência Viagem  \
# 0                                     Sem informação
# 1                                     Sem informação
# 2                                     Sem informação
# 3  Informação protegida por sigilo nos termos da ...
# 4                                     Sem informação
#
#    Código do órgão superior  \
# ...

# %%
inverted = lbl.inverse_transform(df_pca)
print(inverted)
# Out:
# ['000120/20' '000076/20' '000139/20' ... 'Sem informação' 'Sem informação'
#  'Sem informação']

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
df = df.drop(labels = 'Situação', axis = 1)

# %%
df['Viagem Urgente'].replace({'Left': 0, 'Right': 1}, inplace=True)

# %%
df.head()
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             16889781                 000120/20
# 1                             16910306                 000076/20
# 2                             16911615                 000139/20
# 3                             17059467           Informações pro
# 4                             17063782                 000001/21
#
#    Viagem Urgente                      Justificativa Urgência Viagem  \
# 0             321                                     Sem informação
# 1             200                                     Sem informação
# 2             374                                     Sem informação
# 3           28673  Informação protegida por sigilo nos termos da ...
# 4               0                                     Sem informação
#
#    Código do órgão superior  \
# 0                     26000
# 1                     20113
# 2                     26000
# 3                     30000
# ...
